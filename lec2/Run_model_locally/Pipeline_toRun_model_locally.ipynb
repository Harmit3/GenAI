# %%
# !pip install transformers

# %%
import os

os.environ["HF_TOKEN"]="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"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model_name="google/gemma-3-1b-it"

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name)

# %%
input_prompt = [
     "The capital of Canada is"
]

# %%
input_prompt = [
     "The capital of Canada is"
]
tokenized = tokenizer(input_prompt,return_tensors="pt")

# %%
tokenized
# Out:
# {'input_ids': tensor([[   2,  818, 5279,  529, 7203,  563]]), 'attention_mask': tensor([[1, 1, 1, 1, 1, 1]])}

# %%
tokenized.input_ids
# Out:
# tensor([[   2,  818, 5279,  529, 7203,  563]])

# %%
import torch

model=AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16
)
# Out:
# Loading weights:   0%|          | 0/340 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %%
gen_result = model.generate(tokenized.input_ids, max_new_tokens=50)

# %%
output=tokenizer.batch_decode(gen_result)
output
# Out:
# ['<bos>The capital of Canada is Ottawa. Ottawa is a vibrant city with a rich history, and it’s a popular destination for tourists.\n\nDo you want to know more about Ottawa? For example, would you like to know:\n\n*   What are some of the major']
